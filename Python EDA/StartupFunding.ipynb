# %% [markdown]
# ## Project Name - Startup Funding
# ### Project Type - EDA (Exploratory Data Analysis)¶

# %% [markdown]
# Startup funding EDA is the process of exploring, cleaning, and analyzing data about startups and their funding patterns. The goal is to uncover trends, insights, and patterns in how startups receive investments, which industries attract the most money, and who the most active investors are.

# %% [markdown]
# ### 1. Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Downloads/startup_funding.csv")
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# 3                 FinTech                      Online Investment
# 4     Fashion and Apparel            Embroiled Clothes For Women
# ...                   ...                                    ...
# 3039                  NaN                                    NaN
# 3040                  NaN                                    NaN
# 3041                  NaN                                    NaN
# 3042                  NaN                                    NaN
# 3043                  NaN                                    NaN
#
#      City  Location                     Investors Name       InvestmentnType  \
# 0         Bengaluru            Tiger Global Management  Private Equity Round
# 1           Gurgaon          Susquehanna Growth Equity              Series C
# 2         Bengaluru              Sequoia Capital India              Series B
# 3         New Delhi                     Vinod Khatumal          Pre-series A
# 4            Mumbai            Sprout Venture Partners            Seed Round
# ...             ...                                ...                   ...
# 3039            NaN        Asia Pacific Internet Group        Private Equity
# 3040            NaN                     KARSEMVEN Fund        Private Equity
# 3041            NaN     Exfinity Fund, GrowX Ventures.        Private Equity
# 3042            NaN                         MakeMyTrip        Private Equity
# 3043            NaN  UK based Group of Angel Investors          Seed Funding
#
#      Amount in USD                            Remarks
# 0     20,00,00,000                                NaN
# 1        80,48,394                                NaN
# 2      1,83,58,860                                NaN
# 3        30,00,000                                NaN
# 4        18,00,000                                NaN
# ...            ...                                ...
# 3039     45,00,000                                NaN
# 3040      8,25,000                Govt backed VC Fund
# 3041     15,00,000                                NaN
# 3042           NaN  Strategic Funding, Minority stake
# 3043      1,40,000                                NaN
#
# [3044 rows x 10 columns]

# %% [markdown]
# ### 2. Data Pre-processing

# %%
df.head(10)
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
# 5      6      13/01/2020                         Pando            Logistics
# 6      7      10/01/2020                        Zomato          Hospitality
# 7      8      12/12/2019                        Ecozen           Technology
# 8      9      06/12/2019                      CarDekho           E-Commerce
# 9     10      03/12/2019                  Dhruva Space            Aerospace
#
#                                 SubVertical City  Location  \
# 0                                E-learning      Bengaluru
# 1                 App based shuttle service        Gurgaon
# 2     Retailer of baby and toddler products      Bengaluru
# 3                         Online Investment      New Delhi
# 4               Embroiled Clothes For Women         Mumbai
# 5  Open-market, freight management platform        Chennai
# 6             Online Food Delivery Platform        Gurgaon
# 7                                  Agritech           Pune
# 8                                Automobile        Gurgaon
# 9                   Satellite Communication      Bengaluru
#
#                    Investors Name       InvestmentnType Amount in USD Remarks
# 0         Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# 1       Susquehanna Growth Equity              Series C     80,48,394     NaN
# 2           Sequoia Capital India              Series B   1,83,58,860     NaN
# 3                  Vinod Khatumal          Pre-series A     30,00,000     NaN
# 4         Sprout Venture Partners            Seed Round     18,00,000     NaN
# 5               Chiratae Ventures              Series A     90,00,000     NaN
# 6                   Ant Financial  Private Equity Round  15,00,00,000     NaN
# 7     Sathguru Catalyzer Advisors              Series A     60,00,000     NaN
# 8     Ping An Global Voyager Fund              Series D   7,00,00,000     NaN
# 9  Mumbai Angels, Ravikanth Reddy                  Seed   5,00,00,000     NaN

# %%
df.tail(10)
# Out:
#       Sr No Date dd/mm/yyyy      Startup Name Industry Vertical SubVertical  \
# 3034   3035      24/01/2015        Aasaanjobs               NaN         NaN
# 3035   3036      24/01/2015          Impartus               NaN         NaN
# 3036   3037      25/01/2015        Thrill App               NaN         NaN
# 3037   3038      27/01/2015      CarDekho.com               NaN         NaN
# 3038   3039      28/01/2015     Grabhouse.com               NaN         NaN
# 3039   3040      29/01/2015        Printvenue               NaN         NaN
# 3040   3041      29/01/2015          Graphene               NaN         NaN
# 3041   3042      30/01/2015    Mad Street Den               NaN         NaN
# 3042   3043      30/01/2015         Simplotel               NaN         NaN
# 3043   3044      31/01/2015  couponmachine.in               NaN         NaN
#
#      City  Location                           Investors Name InvestmentnType  \
# 3034            NaN  Inventus Capital Partners, IDG Ventures    Seed Funding
# 3035            NaN                    Kaizen Private Equity  Private Equity
# 3036            NaN                People Group (Shaadi.com)  Private Equity
# 3037            NaN      Hillhouse Capital, Tybourne Capital  Private Equity
# 3038            NaN         Kalaari Capital, Sequoia Capital  Private Equity
# 3039            NaN              Asia Pacific Internet Group  Private Equity
# 3040            NaN                           KARSEMVEN Fund  Private Equity
# 3041            NaN           Exfinity Fund, GrowX Ventures.  Private Equity
# 3042            NaN                               MakeMyTrip  Private Equity
# 3043            NaN        UK based Group of Angel Investors    Seed Funding
#
#      Amount in USD                            Remarks
# 3034     15,00,000                                NaN
# 3035           NaN                           Series A
# 3036     10,00,000                  Strategic Funding
# 3037   5,00,00,000                           Series B
# 3038     25,00,000                           Series A
# 3039     45,00,000                                NaN
# 3040      8,25,000                Govt backed VC Fund
# 3041     15,00,000                                NaN
# 3042           NaN  Strategic Funding, Minority stake
# 3043      1,40,000                                NaN

# %%
df.shape
# Out:
# (3044, 10)

# %%
list(df.columns)
# Out:
# ['Sr No',
#  'Date dd/mm/yyyy',
#  'Startup Name',
#  'Industry Vertical',
#  'SubVertical',
#  'City  Location',
#  'Investors Name',
#  'InvestmentnType',
#  'Amount in USD',
#  'Remarks']

# %%
df.describe()
# Out:
#              Sr No
# count  3044.000000
# mean   1522.500000
# std     878.871435
# min       1.000000
# 25%     761.750000
# 50%    1522.500000
# 75%    2283.250000
# max    3044.000000

# %% [markdown]
# ### 3. Data Cleaning

# %%
df.isnull().sum()
# Out:
# Sr No                   0
# Date dd/mm/yyyy         0
# Startup Name            0
# Industry Vertical     171
# SubVertical           936
# City  Location        180
# Investors Name         24
# InvestmentnType         4
# Amount in USD         960
# Remarks              2625
# dtype: int64

# %%
df['Industry Vertical']=df['Industry Vertical'].fillna('Unknown')
df['City  Location']=df['City  Location'].fillna('Unknown')
df['Investors Name']=df['Investors Name'].fillna('Unknown')
df['InvestmentnType']=df['InvestmentnType'].fillna('Unknown')
df['Amount in USD'] = pd.to_numeric(df['Amount in USD'], errors='coerce')
df['Amount in USD']=df['Amount in USD'].fillna(df['Amount in USD'].mean())
df.drop('Remarks',axis=1,inplace=True)
df.drop('SubVertical',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Sr No                0
# Date dd/mm/yyyy      0
# Startup Name         0
# Industry Vertical    0
# City  Location       0
# Investors Name       0
# InvestmentnType      0
# Amount in USD        0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    3044
# Name: count, dtype: int64

# %%
df.columns = df.columns.str.replace(' ', '')
df
# Out:
#       SrNo Datedd/mm/yyyy                   StartupName     IndustryVertical  \
# 0        1     09/01/2020                        BYJU’S               E-Tech
# 1        2     13/01/2020                        Shuttl       Transportation
# 2        3     09/01/2020                     Mamaearth           E-commerce
# 3        4     02/01/2020  https://www.wealthbucket.in/              FinTech
# 4        5     02/01/2020                        Fashor  Fashion and Apparel
# ...    ...            ...                           ...                  ...
# 3039  3040     29/01/2015                    Printvenue              Unknown
# 3040  3041     29/01/2015                      Graphene              Unknown
# 3041  3042     30/01/2015                Mad Street Den              Unknown
# 3042  3043     30/01/2015                     Simplotel              Unknown
# 3043  3044     31/01/2015              couponmachine.in              Unknown
#
#      CityLocation                      InvestorsName       InvestmentnType  \
# 0       Bengaluru            Tiger Global Management  Private Equity Round
# 1         Gurgaon          Susquehanna Growth Equity              Series C
# 2       Bengaluru              Sequoia Capital India              Series B
# 3       New Delhi                     Vinod Khatumal          Pre-series A
# 4          Mumbai            Sprout Venture Partners            Seed Round
# ...           ...                                ...                   ...
# 3039      Unknown        Asia Pacific Internet Group        Private Equity
# 3040      Unknown                     KARSEMVEN Fund        Private Equity
# 3041      Unknown     Exfinity Fund, GrowX Ventures.        Private Equity
# 3042      Unknown                         MakeMyTrip        Private Equity
# 3043      Unknown  UK based Group of Angel Investors          Seed Funding
#
#       AmountinUSD
# 0       4200000.0
# 1       4200000.0
# 2       4200000.0
# 3       4200000.0
# 4       4200000.0
# ...           ...
# 3039    4200000.0
# 3040    4200000.0
# 3041    4200000.0
# 3042    4200000.0
# 3043    4200000.0
#
# [3044 rows x 8 columns]

# %% [markdown]
# ### 4. Findings

# %% [markdown]
# ### 1. Top 5 Highest number of Startups in India

# %%
df['CityLocation'] = df['CityLocation'].str.strip().str.lower().replace({
    'Bangalore': 'bengaluru',
    'Bengaluru': 'bengaluru'
})
high=df.groupby('CityLocation')['StartupName'].nunique().sort_values(ascending=False).head(5)
city=high.head(5)
print("Highest Number of Startups in India\n",city)
# Out:
# Highest Number of Startups in India
#  CityLocation
# bangalore    572
# mumbai       483
# new delhi    369
# gurgaon      233
# unknown      176
# Name: StartupName, dtype: int64

# %%
city.plot(kind='bar',color='#BCC75F')
plt.show()

# %% [markdown]
# ### Conclusion :
# The dataset reveals that **Bengaluru** hosts the **highest** number of startups in India. This concentration highlights the city’s role as a breeding ground for innovation, supported by favorable infrastructure, skilled talent, and a strong investor network.

# %% [markdown]
# ### 2. Startup's based on Bengaluru City

# %%
bengaluru_startups=df[df['CityLocation']=='bengaluru']
bengaluru_startups
# Out:
#      SrNo Datedd/mm/yyyy               StartupName  \
# 0       1     09/01/2020                    BYJU’S
# 2       3     09/01/2020                 Mamaearth
# 9      10     03/12/2019              Dhruva Space
# 11     12     17/12/2019                Healthians
# 12     13     16/12/2019                   Licious
# ..    ...            ...                       ...
# 453   454     14/12/2017  Transversal Technologies
# 455   456     14/12/2017                  HomeLane
# 460   461     19/12/2017               Springboard
# 463   464     20/12/2017                Your Quote
# 466   467     21/12/2017                  EasyEcom
#
#                  IndustryVertical CityLocation  \
# 0                          E-Tech    bengaluru
# 2                      E-commerce    bengaluru
# 9                       Aerospace    bengaluru
# 11   B2B-focused foodtech startup    bengaluru
# 12                     E-Commerce    bengaluru
# ..                            ...          ...
# 453                    Technology    bengaluru
# 455                    E-Commerce    bengaluru
# 460                    Technology    bengaluru
# 463                    Technology    bengaluru
# 466                    E-Commerce    bengaluru
#
#                                          InvestorsName       InvestmentnType  \
# 0                              Tiger Global Management  Private Equity Round
# 2                                Sequoia Capital India              Series B
# 9                       Mumbai Angels, Ravikanth Reddy                  Seed
# 11             Paytm, NPTK, Sabre Partners and Neoplux              Series C
# 12                                  Vertex Growth Fund              Series E
# ..                                                 ...                   ...
# 453                                    Matrix Partners        Private Equity
# 455    Accel Partners, Sequoia Capital, RB Investments        Private Equity
# 460              Costanoa, Learn Capital, Jyoti Bansal        Private Equity
# 463         Axilor Ventures, E-City VEntures Atul Goel        Private Equity
# 466  Ambarish Gupta, Aneesh Reddy, Bold Ventures, V...    Seed/Angel Funding
#
#      AmountinUSD
# 0      4200000.0
# 2      4200000.0
# 9      4200000.0
# 11     4200000.0
# 12     4200000.0
# ..           ...
# 453    4200000.0
# 455    4200000.0
# 460    4200000.0
# 463    4200000.0
# 466    4200000.0
#
# [141 rows x 8 columns]

# %% [markdown]
# ### 3. List of Top 5 Investors

# %%
top_investors = df['InvestorsName'].value_counts().head(5)
top_investors
# Out:
# InvestorsName
# Undisclosed Investors    39
# Undisclosed investors    30
# Ratan Tata               25
# Unknown                  24
# Indian Angel Network     23
# Name: count, dtype: int64

# %%
top_investors.plot(kind='line',figsize=(10,5),color='skyblue')
plt.show()

# %% [markdown]
# ### Conclusion :
#
# The data shows that **Undisclosed Investors** have made the **highest** number of investments, followed by Ratan Tata, Unknown, and Indian Angel Network. If we combine “Undisclosed Investors” and “Undisclosed investors” (as they refer to the same category), the total becomes 69 investments, making them the clear leading investor group.

# %% [markdown]
# ### 4.Most Recently Started Startup's

# %%
df['Datedd/mm/yyyy'] = pd.to_datetime(df['Datedd/mm/yyyy'], errors='coerce')
most=df.groupby('InvestorsName')['Datedd/mm/yyyy'].max().sort_values(ascending=False).head(5)
most
# Out:
# InvestorsName
# Ant Financial             2020-10-01
# Tiger Global Management   2020-09-01
# Sequoia Capital India     2020-09-01
# Sprout Venture Partners   2020-02-01
# Vinod Khatumal            2020-02-01
# Name: Datedd/mm/yyyy, dtype: datetime64[ns]

# %% [markdown]
# ### 5. Top 5 Cities by Total Funding Amount

# %%
city_funding = df.groupby('CityLocation')['AmountinUSD'].sum().dropna().head(5)

plt.figure(figsize=(8,8))
plt.pie(city_funding, labels=city_funding.index, autopct="%1.1f%%", startangle=140)
plt.title("Top 5 Cities by Total Funding Amount")
plt.show()

# %% [markdown]
# ### 6. Yearly Observations

# %%
sns.kdeplot(df['Datedd/mm/yyyy'],fill='True',color='skyblue')
plt.show()

# %% [markdown]
# ### Observation :
#
# The majority of startups were founded between **2015 and 2017**

# %% [markdown]
# ### 7.Top 5 industries with the most startups

# %%
fg = df.groupby('IndustryVertical')['StartupName'].count().sort_values(ascending=False).head(5)
print(fg)
# Out:
# IndustryVertical
# Consumer Internet    941
# Technology           478
# eCommerce            186
# Unknown              171
# Healthcare            70
# Name: StartupName, dtype: int64

# %%
fg.plot(kind='barh',color='green')
fg.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9296\1258853019.py in ?()
#       1 fg.plot(kind='barh',color='green')
# ----> 2 fg.show()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'show'

# %% [markdown]
# ### Observation :
#
# The **Consumer Internet** sector leads in the number of startups.

# %% [raw]
# ### Final Conclusions :
#
# The analysis highlights a dynamic Indian startup ecosystem. Most startups were founded between 2015 and 2017, with Bengaluru hosting the highest number, reflecting its role as a major innovation hub. In terms of funding, Gurgaon leads, indicating stronger capital inflows despite fewer startups. Undisclosed Investors dominate the investment landscape, followed by Ratan Tata, Unknown, and the Indian Angel Network, with a combined total of 69 investments for the undisclosed category. Overall, the data underscores the concentration of entrepreneurial activity in key cities and the critical role of both visible and hidden investors in driving India’s startup growth.
