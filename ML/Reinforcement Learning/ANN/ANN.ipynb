# %% [markdown]
# # **Importing Libraries**

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## **Load Dataset**

# %%
housing=fetch_california_housing()
x=pd.DataFrame(housing.data,columns=housing.feature_names)
y=housing.target

# %% [markdown]
# ## **Split Datasets**

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ## **Feature Scaling**

# %%
scaler = StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %% [markdown]
# ## **Build the ANN**

# %%
from tensorflow.keras.layers import Input
model = Sequential([Input(shape=(x_train_scaled.shape[1],)),
                    Dense(64,activation='relu'),
                    Dense(32,activation='relu'),
                    Dense(16,activation='relu'),
                    Dense(1)
                    ])

# %% [markdown]
# ## **Compile The Model**

# %%
model.compile(optimizer=Adam(learning_rate=0.001),loss='mse' , metrics=['mae'])

# %% [markdown]
# ## **Train The Model**

# %%
history = model.fit(x_train_scaled, y_train, validation_split=0.2, epochs=50,batch_size=32)
# Out:
# Epoch 1/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.9330 - mae: 0.6551 - val_loss: 0.4962 - val_mae: 0.4956
# Epoch 2/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4449 - mae: 0.4589 - val_loss: 0.4080 - val_mae: 0.4515
# Epoch 3/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3711 - mae: 0.4311 - val_loss: 0.4107 - val_mae: 0.4719
# Epoch 4/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3433 - mae: 0.4153 - val_loss: 0.3678 - val_mae: 0.4313
# Epoch 5/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3265 - mae: 0.4016 - val_loss: 0.3550 - val_mae: 0.4043
# Epoch 6/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3180 - mae: 0.3942 - val_loss: 0.3495 - val_mae: 0.4004
# Epoch 7/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3087 - mae: 0.3868 - val_loss: 0.3257 - val_mae: 0.3972
# Epoch 8/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2994 - mae: 0.3813 - val_loss: 0.3419 - val_mae: 0.3854
# Epoch 9/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3032 - mae: 0.3794 - val_loss: 0.3353 - val_mae: 0.4193
# Epoch 10/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2911 - mae: 0.3726 - val_loss: 0.3239 - val_mae: 0.4038
# Epoch 11/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2892 - mae: 0.3720 - val_loss: 0.3222 - val_mae: 0.3964
# Epoch 12/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2857 - mae: 0.3688 - val_loss: 0.3202 - val_mae: 0.3783
# Epoch 13/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2861 - mae: 0.3702 - val_loss: 0.3198 - val_mae: 0.3780
# Epoch 14/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2809 - mae: 0.3661 - val_loss: 0.3135 - val_mae: 0.3815
# Epoch 15/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2798 - mae: 0.3644 - val_loss: 0.3143 - val_mae: 0.3823
# Epoch 16/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2819 - mae: 0.3656 - val_loss: 0.3129 - val_mae: 0.3845
# Epoch 17/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2760 - mae: 0.3615 - val_loss: 0.3064 - val_mae: 0.3800
# Epoch 18/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2766 - mae: 0.3632 - val_loss: 0.3104 - val_mae: 0.3792
# Epoch 19/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2726 - mae: 0.3594 - val_loss: 0.3015 - val_mae: 0.3740
# Epoch 20/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2706 - mae: 0.3574 - val_loss: 0.3085 - val_mae: 0.3786
# Epoch 21/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2710 - mae: 0.3575 - val_loss: 0.3083 - val_mae: 0.3866
# Epoch 22/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2670 - mae: 0.3542 - val_loss: 0.3067 - val_mae: 0.3878
# Epoch 23/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2692 - mae: 0.3534 - val_loss: 0.3065 - val_mae: 0.3703
# Epoch 24/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2714 - mae: 0.3571 - val_loss: 0.2982 - val_mae: 0.3781
# Epoch 25/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2627 - mae: 0.3518 - val_loss: 0.2995 - val_mae: 0.3725
# Epoch 26/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2609 - mae: 0.3504 - val_loss: 0.2949 - val_mae: 0.3689
# Epoch 27/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2600 - mae: 0.3501 - val_loss: 0.2915 - val_mae: 0.3656
# Epoch 28/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2662 - mae: 0.3521 - val_loss: 0.2943 - val_mae: 0.3636
# Epoch 29/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2567 - mae: 0.3477 - val_loss: 0.3068 - val_mae: 0.3689
# Epoch 30/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2576 - mae: 0.3469 - val_loss: 0.3016 - val_mae: 0.3757
# Epoch 31/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2569 - mae: 0.3469 - val_loss: 0.2975 - val_mae: 0.3650
# Epoch 32/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2545 - mae: 0.3450 - val_loss: 0.2944 - val_mae: 0.3704
# Epoch 33/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2520 - mae: 0.3437 - val_loss: 0.3017 - val_mae: 0.3641
# Epoch 34/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2535 - mae: 0.3437 - val_loss: 0.2943 - val_mae: 0.3785
# Epoch 35/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2530 - mae: 0.3439 - val_loss: 0.2940 - val_mae: 0.3723
# Epoch 36/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2513 - mae: 0.3411 - val_loss: 0.2850 - val_mae: 0.3612
# Epoch 37/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2493 - mae: 0.3403 - val_loss: 0.2979 - val_mae: 0.3889
# Epoch 38/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2492 - mae: 0.3405 - val_loss: 0.2900 - val_mae: 0.3621
# Epoch 39/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2465 - mae: 0.3384 - val_loss: 0.2926 - val_mae: 0.3622
# Epoch 40/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2464 - mae: 0.3373 - val_loss: 0.2990 - val_mae: 0.3697
# Epoch 41/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2466 - mae: 0.3382 - val_loss: 0.2999 - val_mae: 0.3631
# Epoch 42/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2442 - mae: 0.3375 - val_loss: 0.2995 - val_mae: 0.3670
# Epoch 43/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2443 - mae: 0.3363 - val_loss: 0.2946 - val_mae: 0.3554
# Epoch 44/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2463 - mae: 0.3377 - val_loss: 0.2808 - val_mae: 0.3622
# Epoch 45/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2422 - mae: 0.3357 - val_loss: 0.3083 - val_mae: 0.3880
# Epoch 46/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2404 - mae: 0.3336 - val_loss: 0.2855 - val_mae: 0.3581
# Epoch 47/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2381 - mae: 0.3308 - val_loss: 0.2876 - val_mae: 0.3634
# Epoch 48/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2368 - mae: 0.3322 - val_loss: 0.2861 - val_mae: 0.3553
# Epoch 49/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2369 - mae: 0.3309 - val_loss: 0.3142 - val_mae: 0.3968
# Epoch 50/50
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2379 - mae: 0.3327 - val_loss: 0.2833 - val_mae: 0.3629

# %% [markdown]
# ## **Evaluate The Model**

# %%
loss,mae=model.evaluate(x_test_scaled,y_test)
print(f"Test MAE : {mae}")
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2748 - mae: 0.3567
# Test MAE : 0.3567386865615845

# %% [markdown]
# ## **Make Predictions**

# %%
pred=model.predict(x_test_scaled)
print("First 5 Predictions :",pred[:5])
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# First 5 Predictions : [[0.6100189]
#  [0.9890841]
#  [4.3479652]
#  [2.3549592]
#  [2.6899514]]
