# %% [markdown]
# # Logistic Regression - Breast Cancer Detection

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer

# %%
# Load the dataset
data=load_breast_cancer(as_frame=True)

# convert it to a dataframe
df=data.frame
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
# Show the first 5 rows
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.shape
# Out:
# (569, 31)

# %%
# Check for null values
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
# Check for duplicates
duplicate_count=df.duplicated().sum()
print(f"Number of duplicate rows : {duplicate_count}")
# Out:
# Number of duplicate rows : 0

# %%
# Check outliers for 'mean radius' using IQR
Q1=df['mean radius'].quantile(0.25)
Q3=df['mean radius'].quantile(0.75)
IQR = Q3-Q1

#Outlier Range

lower=Q1-1.5*IQR
upper=Q3+1.5*IQR

outliers=df[(df['mean radius']<lower) | (df['mean radius']>upper)]
print(f"Number of outliers in mean radius : {outliers.shape[0]}")
# Out:
# Number of outliers in mean radius : 14

# %% [markdown]
# ### These 14 data points have a 'mean radius' either too small or too large compared to most of the other values.
#
# In a boxplot, they appear as dots outside the "whiskers" (the normal range).

# %% [markdown]
# ## Visualize Outliers using BoxPlot

# %%
sns.boxplot(df['mean radius'],color='skyblue')
plt.title("Outliers in mean radius")
plt.show()

# %%
df.shape

# %%
# remove outliers in 'mean radius' only

clean_outliers=df[(df['mean radius']>=lower) & (df['mean radius']<=upper)]
print(f"New shape after removing outliers {clean_outliers.shape}")
# Out:
# New shape after removing outliers (555, 31)

# %% [markdown]
# ## Split features & Target

# %%
x=df.drop('target',axis=1)
y=df['target']

# 80% Train , 20% Test
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ## Train Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

#create model & fit

model=LogisticRegression(max_iter=10000)
model.fit(x_train,y_train)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Predict on test data
y_pred=model.predict(x_test)

# Accuracy
print("Accuracy : ",accuracy_score(y_test,y_pred))
print("\n")

# Confusion matrix
print("Confusion Matrix :",confusion_matrix(y_test,y_pred))
print("\n")

# Classification Report
print("classification Report :",classification_report(y_test,y_pred))

# %% [markdown]
# Class 0 means the person is diagnosed with cancer
#
# Class 1 means the person is not diagnosed with cancer

# %%
# Generate Confusion Matrix
cm=confusion_matrix(y_test,y_pred)

#plot heatmap
sns.heatmap(cm,annot=True,fmt='d', cmap='Blues',xticklabels=['0', '1'], yticklabels=['0', '1'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Metrics")
plt.show()

# %% [markdown]
# 🔹 **Accuracy**: 0.9561 (≈ 96%)
#
# This means the model correctly predicted whether the tumor was malignant or benign for 96% of the test cases.
#
#
# 🔹 **Confusion Matrix:**
#
#
# Term	Meaning	Count
#
#
# True Negative (TN)	Correctly predicted  	39  diagnosed with cancer
#
# False Positive (FP)	Mistakenly predicted 4  diagnosed with cancer
#
# False Negative (FN)	Mistakenly predicted  	1 not diagnosed with cancer
#
# True Positive (TP)	Correctly predicted 70 not diagnosed with cancer
#
#
# 🔹 **Precision**:
#
# Class 0 : 97%
#
# Class 1 : 95%
#
# Precision tells us when the model predicts a class, how often it's right.
#
# 🔹 **Recall**:
#
# Class 0: 91%
#
# Class 1: 99%
#
# Recall tells us how well the model finds all positive cases.
#
# 🔹** F1-Score**:
#
# Class 0: 0.94
#
# Class 1: 0.97
